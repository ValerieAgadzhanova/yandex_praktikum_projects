# %% [markdown]
# # Анализ поведения пользователей в мобильном приложении

# %% [markdown]
# **Цель исследования:**
#
# Проанализировать поведение пользователей в приложении "Ненужные вещи".
#
# **Описание данных:**
#
# В датасете содержатся данные пользователей, впервые совершивших действия в приложении после 7 октября 2019 года.
#
# Колонки в *mobile_sources.csv*:
#
# - `userId` — идентификатор пользователя,
# - `source` — источник, с которого пользователь установил приложение.
#
# Колонки в mobile_dataset.csv: **
#
# - `event.time` — время совершения,
# - `user.id` — идентификатор пользователя,
# - `event.name` — действие пользователя.
#
# Виды действий:
#
# - `advert_open` — открыл карточки объявления,
# - `photos_show` — просмотрел фотографий в объявлении,
# - `tips_show` — увидел рекомендованные объявления,
# - `tips_click` — кликнул по рекомендованному объявлению,
# - `contacts_show` и `show_contacts` — посмотрел номер телефона,
# - `contacts_call` — позвонил по номеру из объявления,
# - `map` — открыл карту объявлений,
# - `search_1`—`search_7` — разные действия, связанные с поиском по сайту,
# - `favorites_add` — добавил объявление в избранное.

# %% [markdown]
# ## Общая информация

# %% [markdown]
# - Импорт библиотек и датасетов
# - Просмотр общей информации
# -  Определение проблем в данных - для устранения на этапе предобработки

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# - Устранение найденых проблем с 1го этапа (смена типа ячеек/заполнение или удаление пропусков)
# - Поиск дубликатов и устранение дубликатов
# - Поиск и устранение неявных дубликатов
# - Выделение отдельных столбцов с датой

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# Определить:
# - Какой период данных (минимальная - максимальная даты)
# - Какие источники есть в логах
# - Из каких источников приходит больше всего уникальных пользователей
# - Какие события есть в логах и сколько пользователей совершили каждое из них
# - Сколько уникальных пользоватей в логе
# - Сколько действий в среднем приходится на одного пользователя
# - Связь целевого события (просмотра контактов) и других действий пользователей.
# - Какие действия чаще совершают те пользователи, которые просматривают контакты.
# - Время пользовательской сессии
# - Типичный сценарий использования приложения
# - Время проведенное в приложении до совершения целевого действия

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# **Первая гипотеза**
#
# Одни пользователи совершают действия *tips_show* и *tips_click*, другие — только *tips_show*. Проверить: конверсия в просмотры контактов различается у этих двух групп.
#
# **Вторая гипотеза**
# Конверсия пользователей, просмотревших объявления с фотографией, в целевое действие - *contacts_show* выше, чем у пользователей, просмотревших объявления без фото.

# %% [markdown]
# ## Общие выводы

# %% [markdown]
# Написать общий вывод по полученым результатам исследования.
